# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('sinasc_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1        2        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2        3        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3        4        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4        5        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
#
#    munResLat munResLon  munResAlt  munResArea
# 0  -11.93554 -61.99982      338.0    7067.025
# 1  -11.93554 -61.99982      338.0    7067.025
# 2  -11.93554 -61.99982      338.0    7067.025
# 3  -12.13178 -61.85308      397.0    3958.273
# 4  -11.93554 -61.99982      338.0    7067.025
#
# [5 rows x 69 columns]

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
#        'munResUf', 'munResLat', 'munResLon', 'munResAlt', 'munResArea'],
#       dtype='object')

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
#usar o groupby para o cálculo

df_1 = sinasc_raw[['IDADEMAE', 'IDADEPAI', 'munResNome']]
df_1_media = df_1.groupby(by='munResNome').mean().round(0)
df_1_media.head()
# Out:
#                          IDADEMAE  IDADEPAI
# munResNome
# Alta Floresta D'Oeste        26.0      30.0
# Alto Alegre dos Parecis      25.0      29.0
# Alto Paraíso                 25.0      29.0
# Alvorada D'Oeste             26.0      31.0
# Ariquemes                    26.0      32.0

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
# mostra qual o tipo de dados da coluna DTNASC

print(sinasc_raw['DTNASC'].dtype)
# Out:
# object

# %%
# cria um df baseado no data do meu aniversário
df_2 = sinasc_raw[sinasc_raw['DTNASC']=='2019-04-01']

# agrupa os dados pela escolaridade de mãe e sexo e retorna a média do peso
table = pd.pivot_table(df_2, values='PESO', index=['ESCMAE'], columns=['SEXO']).round(2)

table
# Out:
# SEXO             Feminino  Masculino
# ESCMAE
# 12 anos ou mais   3143.57    3493.33
# 4 a 7 anos        3207.14    3467.50
# 8 a 11 anos       3188.10    3297.59

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
df_2 = sinasc_raw.groupby(['munResNome']).count()
df_2.sort_values(by='ORIGEM',ascending=True)
# Out:
#                            ORIGEM  CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  \
# munResNome
# Município ignorado - RO         1         1           1        1         1
# Castanheiras                   32        32          32       32        32
# Pimenteiras do Oeste           40        40          40       40        40
# Primavera de Rondônia          43        43          43       43        43
# Parecis                        44        44          44       44        44
# Rio Crespo                     50        50          50       50        50
# São Felipe D'Oeste             54        54          54       54        54
# Teixeirópolis                  64        64          64       64        64
# Cacaulândia                    75        75          75       75        75
# Cabixi                         80        79          80       80        80
# Vale do Paraíso                81        81          81       81        81
# Ministro Andreazza             84        84          84       84        84
# Vale do Anari                  93        92          93       93        93
# Theobroma                      97        97          97       97        97
# Novo Horizonte do Oeste        98        98          98       98        98
# Santa Luzia D'Oeste            99        99          99       99        99
# Nova União                    104       103         104      104       104
# Itapuã do Oeste               109       109         109      109       109
# Governador Jorge Teixeira     112       112         112      112       112
# Corumbiara                    127       126         127      127       127
# Alto Alegre dos Parecis       154       154         154      154       154
# Chupinguaia                   162       159         162      162       162
# Mirante da Serra              164       163         164      164       164
# Campo Novo de Rondônia        166       165         166      166       166
# Seringueiras                  168       168         168      168       168
# Urupá                         170       169         170      170       170
# Monte Negro                   199       198         199      199       199
# Cujubim                       205       202         205      205       205
# Alvorada D'Oeste              205       205         205      205       205
# Colorado do Oeste             214       214         214      214       214
# Alto Paraíso                  226       226         226      226       226
# Costa Marques                 233       232         233      233       233
# Cerejeiras                    237       235         237      237       237
# Nova Brasilândia D'Oeste      261       261         261      261       261
# São Francisco do Guaporé      303       303         303      303       303
# Presidente Médici             304       303         304      304       304
# Candeias do Jamari            337       333         337      337       337
# São Miguel do Guaporé         353       353         353      353       353
# Alta Floresta D'Oeste         367       365         367      367       367
# Nova Mamoré                   432       424         432      432       432
# Espigão D'Oeste               450       449         450      450       450
# Machadinho D'Oeste            500       498         500      500       500
# Buritis                       583       579         583      583       583
# Pimenta Bueno                 616       616         616      616       616
# Ouro Preto do Oeste           631       631         631      631       631
# Guajará-Mirim                 781       763         781      781       781
# Jaru                          881       879         881      881       881
# Rolim de Moura                927       925         927      927       927
# Cacoal                       1374      1371        1374     1374      1374
# Vilhena                      1590      1582        1590     1590      1590
# Ariquemes                    1729      1724        1729     1729      1729
# Ji-Paraná                    2182      2179        2182     2182      2182
# Porto Velho                  8437      8402        8437     8437      8437
#
#                            ESTCIVMAE  ESCMAE  CODOCUPMAE  QTDFILVIVO  \
# munResNome
# Município ignorado - RO            1       1           1           1
# Castanheiras                      32      32          30          32
# Pimenteiras do Oeste              40      40          38          40
# Primavera de Rondônia             43      43          12          43
# Parecis                           44      44          34          43
# Rio Crespo                        49      49          48          47
# São Felipe D'Oeste                54      54          31          53
# Teixeirópolis                     64      64          58          64
# Cacaulândia                       74      74          72          75
# Cabixi                            80      80          68          80
# Vale do Paraíso                   81      81          74          79
# Ministro Andreazza                84      84          77          84
# Vale do Anari                     91      92          88          92
# Theobroma                         97      95          93          95
# Novo Horizonte do Oeste           96      98          92          97
# Santa Luzia D'Oeste               97      98          96          99
# Nova União                       100     103          90         103
# Itapuã do Oeste                  108     107          98         100
# Governador Jorge Teixeira        111     111         110         108
# Corumbiara                       127     127         117         126
# Alto Alegre dos Parecis          151     151         146         152
# Chupinguaia                      160     160         132         160
# Mirante da Serra                 164     164         147         163
# Campo Novo de Rondônia           164     164         158         131
# Seringueiras                     167     167         134         167
# Urupá                            168     168         151         169
# Monte Negro                      194     188         192         192
# Cujubim                          200     203         197         203
# Alvorada D'Oeste                 199     202         190         202
# Colorado do Oeste                214     213         197         214
# Alto Paraíso                     223     226         218         221
# Costa Marques                    221     228         189         228
# Cerejeiras                       235     235         206         233
# Nova Brasilândia D'Oeste         258     259         254         258
# São Francisco do Guaporé         301     301         254         301
# Presidente Médici                301     300         288         301
# Candeias do Jamari               333     332         304         302
# São Miguel do Guaporé            351     352         343         349
# Alta Floresta D'Oeste            361     360         315         362
# Nova Mamoré                      431     430         381         396
# Espigão D'Oeste                  449     450         439         446
# Machadinho D'Oeste               490     494         305         490
# Buritis                          578     579         503         390
# Pimenta Bueno                    615     615         151         610
# Ouro Preto do Oeste              627     629         528         626
# Guajará-Mirim                    778     776         681         769
# Jaru                             874     876         832         874
# Rolim de Moura                   920     916         847         919
# Cacoal                          1364    1370        1346        1368
# Vilhena                         1588    1582        1472        1584
# Ariquemes                       1698    1726        1706        1722
# Ji-Paraná                       2151    2155        2094        2173
# Porto Velho                     8310    8268        7494        7319
#
#                            QTDFILMORT  ...  PARIDADE  KOTELCHUCK  CONTADOR  \
# munResNome                             ...
# Município ignorado - RO             1  ...         1           1         1
# Castanheiras                       32  ...        32          32        32
# Pimenteiras do Oeste               40  ...        40          40        40
# Primavera de Rondônia              43  ...        43          43        43
# Parecis                            42  ...        44          44        44
# Rio Crespo                         47  ...        50          50        50
# São Felipe D'Oeste                 53  ...        54          54        54
# Teixeirópolis                      64  ...        64          64        64
# Cacaulândia                        74  ...        75          75        75
# Cabixi                             80  ...        80          80        80
# Vale do Paraíso                    79  ...        81          81        81
# Ministro Andreazza                 84  ...        84          84        84
# Vale do Anari                      92  ...        93          93        93
# Theobroma                          95  ...        97          97        97
# Novo Horizonte do Oeste            97  ...        98          98        98
# Santa Luzia D'Oeste                98  ...        99          99        99
# Nova União                        103  ...       104         104       104
# Itapuã do Oeste                    98  ...       109         109       109
# Governador Jorge Teixeira         108  ...       112         112       112
# Corumbiara                        126  ...       127         127       127
# Alto Alegre dos Parecis           149  ...       154         154       154
# Chupinguaia                       160  ...       162         162       162
# Mirante da Serra                  162  ...       164         164       164
# Campo Novo de Rondônia            111  ...       166         166       166
# Seringueiras                      167  ...       168         168       168
# Urupá                             170  ...       170         170       170
# Monte Negro                       187  ...       199         199       199
# Cujubim                           201  ...       205         205       205
# Alvorada D'Oeste                  202  ...       205         205       205
# Colorado do Oeste                 214  ...       214         214       214
# Alto Paraíso                      217  ...       226         226       226
# Costa Marques                     226  ...       233         233       233
# Cerejeiras                        231  ...       237         237       237
# Nova Brasilândia D'Oeste          258  ...       261         261       261
# São Francisco do Guaporé          298  ...       303         303       303
# Presidente Médici                 301  ...       304         304       304
# Candeias do Jamari                299  ...       337         337       337
# São Miguel do Guaporé             349  ...       353         353       353
# Alta Floresta D'Oeste             363  ...       367         367       367
# Nova Mamoré                       382  ...       432         432       432
# Espigão D'Oeste                   444  ...       450         450       450
# Machadinho D'Oeste                477  ...       500         500       500
# Buritis                           215  ...       583         583       583
# Pimenta Bueno                     602  ...       616         616       616
# Ouro Preto do Oeste               624  ...       631         631       631
# Guajará-Mirim                     766  ...       781         781       781
# Jaru                              873  ...       881         881       881
# Rolim de Moura                    919  ...       927         927       927
# Cacoal                           1369  ...      1374        1374      1374
# Vilhena                          1582  ...      1590        1590      1590
# Ariquemes                        1717  ...      1729        1729      1729
# Ji-Paraná                        2166  ...      2182        2182      2182
# Porto Velho                      7073  ...      8437        8437      8437
#
#                            munResStatus  munResTipo  munResUf  munResLat  \
# munResNome
# Município ignorado - RO               1           1         1          0
# Castanheiras                         32          32        32         32
# Pimenteiras do Oeste                 40          40        40         40
# Primavera de Rondônia                43          43        43         43
# Parecis                              44          44        44         44
# Rio Crespo                           50          50        50         50
# São Felipe D'Oeste                   54          54        54         54
# Teixeirópolis                        64          64        64         64
# Cacaulândia                          75          75        75         75
# Cabixi                               80          80        80         80
# Vale do Paraíso                      81          81        81         81
# Ministro Andreazza                   84          84        84         84
# Vale do Anari                        93          93        93         93
# Theobroma                            97          97        97         97
# Novo Horizonte do Oeste              98          98        98         98
# Santa Luzia D'Oeste                  99          99        99         99
# Nova União                          104         104       104        104
# Itapuã do Oeste                     109         109       109        109
# Governador Jorge Teixeira           112         112       112        112
# Corumbiara                          127         127       127        127
# Alto Alegre dos Parecis             154         154       154        154
# Chupinguaia                         162         162       162        162
# Mirante da Serra                    164         164       164        164
# Campo Novo de Rondônia              166         166       166        166
# Seringueiras                        168         168       168        168
# Urupá                               170         170       170        170
# Monte Negro                         199         199       199        199
# Cujubim                             205         205       205        205
# Alvorada D'Oeste                    205         205       205        205
# Colorado do Oeste                   214         214       214        214
# Alto Paraíso                        226         226       226        226
# Costa Marques                       233         233       233        233
# Cerejeiras                          237         237       237        237
# Nova Brasilândia D'Oeste            261         261       261        261
# São Francisco do Guaporé            303         303       303        303
# Presidente Médici                   304         304       304        304
# Candeias do Jamari                  337         337       337        337
# São Miguel do Guaporé               353         353       353        353
# Alta Floresta D'Oeste               367         367       367        367
# Nova Mamoré                         432         432       432        432
# Espigão D'Oeste                     450         450       450        450
# Machadinho D'Oeste                  500         500       500        500
# Buritis                             583         583       583        583
# Pimenta Bueno                       616         616       616        616
# Ouro Preto do Oeste                 631         631       631        631
# Guajará-Mirim                       781         781       781        781
# Jaru                                881         881       881        881
# Rolim de Moura                      927         927       927        927
# Cacoal                             1374        1374      1374       1374
# Vilhena                            1590        1590      1590       1590
# Ariquemes                          1729        1729      1729       1729
# Ji-Paraná                          2182        2182      2182       2182
# Porto Velho                        8437        8437      8437       8437
#
#                            munResLon  munResAlt  munResArea
# munResNome
# Município ignorado - RO            0          0           0
# Castanheiras                      32         32          32
# Pimenteiras do Oeste              40         40          40
# Primavera de Rondônia             43         43          43
# Parecis                           44         44          44
# Rio Crespo                        50         50          50
# São Felipe D'Oeste                54         54          54
# Teixeirópolis                     64         64          64
# Cacaulândia                       75         75          75
# Cabixi                            80         80          80
# Vale do Paraíso                   81         81          81
# Ministro Andreazza                84         84          84
# Vale do Anari                     93         93          93
# Theobroma                         97         97          97
# Novo Horizonte do Oeste           98         98          98
# Santa Luzia D'Oeste               99         99          99
# Nova União                       104        104         104
# Itapuã do Oeste                  109        109         109
# Governador Jorge Teixeira        112        112         112
# Corumbiara                       127        127         127
# Alto Alegre dos Parecis          154        154         154
# Chupinguaia                      162        162         162
# Mirante da Serra                 164        164         164
# Campo Novo de Rondônia           166        166         166
# Seringueiras                     168        168         168
# Urupá                            170        170         170
# Monte Negro                      199        199         199
# Cujubim                          205        205         205
# Alvorada D'Oeste                 205        205         205
# Colorado do Oeste                214        214         214
# Alto Paraíso                     226        226         226
# Costa Marques                    233        233         233
# Cerejeiras                       237        237         237
# Nova Brasilândia D'Oeste         261        261         261
# São Francisco do Guaporé         303        303         303
# Presidente Médici                304        304         304
# Candeias do Jamari               337        337         337
# São Miguel do Guaporé            353        353         353
# Alta Floresta D'Oeste            367        367         367
# Nova Mamoré                      432        432         432
# Espigão D'Oeste                  450        450         450
# Machadinho D'Oeste               500        500         500
# Buritis                          583        583         583
# Pimenta Bueno                    616        616         616
# Ouro Preto do Oeste              631        631         631
# Guajará-Mirim                    781        781         781
# Jaru                             881        881         881
# Rolim de Moura                   927        927         927
# Cacoal                          1374       1374        1374
# Vilhena                         1590       1590        1590
# Ariquemes                       1729       1729        1729
# Ji-Paraná                       2182       2182        2182
# Porto Velho                     8437       8437        8437
#
# [53 rows x 68 columns]

# %%
# cria uma pivot table com apenas o nome do munícipio menos citado acima

a = sinasc_raw['munResNome']=='Castanheiras'

table_1 = pd.pivot_table(sinasc_raw[a], 
               values=['IDADEMAE','IDADEPAI'], 
               index=['munResNome'], 
               aggfunc={
                   'IDADEMAE':[np.max, np.min, np.mean],
                   'IDADEPAI':[np.max, np.min, np.mean]
               }
                        )
    
table_1
# Out:
#              IDADEMAE                IDADEPAI
#                  amax amin      mean     amax  amin       mean
# munResNome
# Castanheiras       39   17  27.28125     43.0  17.0  30.392857

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
# converte a coluna DTNASC em datetime

df_3 = sinasc_raw.copy()

df_3['DTNASC'] = pd.to_datetime(sinasc_raw['DTNASC'])

df_3['MES'] = df_3['DTNASC'].dt.month

# %%
df_marco = df_3[df_3['MES']==3]

# %%
df_marco.groupby(by='munResNome').count().sort_values(by='ORIGEM',ascending=True).head(1)
# Out:
#                ORIGEM  CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# munResNome
# Teixeirópolis       3         3           3        3         3          3
#
#                ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# munResNome                                                 ...
# Teixeirópolis       3           3           3           3  ...           3
#
#                CONTADOR  munResStatus  munResTipo  munResUf  munResLat  \
# munResNome
# Teixeirópolis         3             3           3         3          3
#
#                munResLon  munResAlt  munResArea  MES
# munResNome
# Teixeirópolis          3          3           3    3
#
# [1 rows x 69 columns]

# %%
b = sinasc_raw['munResNome']=='Teixeirópolis'

table_2 = pd.pivot_table(sinasc_raw[a], 
               values=['QTDFILVIVO','IDADEMAE','IDADEPAI'], 
               index=['munResNome'], 
               aggfunc={
                   'QTDFILVIVO':[np.max, np.min, np.mean],
                   'IDADEMAE':[np.max, np.min, np.mean],
                   'IDADEPAI':[np.max, np.min, np.mean]
               }
                        )
    
table_2
# Out:
#              IDADEMAE                IDADEPAI                  QTDFILVIVO  \
#                  amax amin      mean     amax  amin       mean       amax
# munResNome
# Castanheiras       39   17  27.28125     43.0  17.0  30.392857        6.0
#
#
#              amin    mean
# munResNome
# Castanheiras  0.0  1.0625

# %% [markdown]
# ### Alguns teste

# %%
table_3 = pd.pivot_table(sinasc_raw, 
               values=['QTDFILVIVO','QTDFILMORT','IDADEMAE','IDADEPAI','PESO'], 
               index=['munResNome'], 
               aggfunc={
                   'PESO':[np.max, np.min, np.mean],
                   'QTDFILMORT':[np.max, np.min, np.mean],
                   'QTDFILVIVO':[np.max, np.min, np.mean],
                   'IDADEMAE':[np.max, np.min, np.mean],
                   'IDADEPAI':[np.max, np.min, np.mean]
               }
                        )
    
table_3
# Out:
#                           IDADEMAE                 IDADEPAI                   \
#                               amax amin       mean     amax  amin       mean
# munResNome
# Alta Floresta D'Oeste           53   14  25.991826     58.0  17.0  29.548701
# Alto Alegre dos Parecis         41   14  24.844156     50.0  16.0  29.179104
# Alto Paraíso                    42   11  24.960177     49.0  21.0  28.833333
# Alvorada D'Oeste                44   15  25.770732     52.0  17.0  30.757282
# Ariquemes                       44   13  25.607866     51.0  20.0  32.466667
# Buritis                         44   14  25.559177     49.0  18.0  30.812500
# Cabixi                          39   13  26.037500     47.0  19.0  34.333333
# Cacaulândia                     42   16  25.546667     50.0  28.0  36.333333
# Cacoal                          47   14  26.890102     66.0  17.0  30.931854
# Campo Novo de Rondônia          40   13  24.825301     40.0  21.0  30.500000
# Candeias do Jamari              45   14  25.243323     41.0  21.0  29.894737
# Castanheiras                    39   17  27.281250     43.0  17.0  30.392857
# Cerejeiras                      53   15  27.240506     52.0  19.0  31.652778
# Chupinguaia                     42   13  25.333333     46.0  20.0  29.629630
# Colorado do Oeste               47   15  27.602804     53.0  23.0  34.354839
# Corumbiara                      43   15  24.716535     52.0  21.0  32.470588
# Costa Marques                   41   12  24.412017     60.0  17.0  30.613636
# Cujubim                         42   14  24.482927     44.0  19.0  31.400000
# Espigão D'Oeste                 44   14  26.093333     86.0  16.0  31.198113
# Governador Jorge Teixeira       41   13  24.401786     37.0  22.0  29.222222
# Guajará-Mirim                   43   13  25.462228     44.0  19.0  30.470588
# Itapuã do Oeste                 46   15  26.064220     73.0  25.0  42.500000
# Jaru                            45   12  25.982974     62.0  19.0  32.197183
# Ji-Paraná                       44   12  26.361137     63.0  15.0  31.132239
# Machadinho D'Oeste              44   13  25.480000     53.0  17.0  31.326923
# Ministro Andreazza              44   17  27.904762     55.0  21.0  33.849315
# Mirante da Serra                46   14  26.304878     56.0  20.0  32.154762
# Monte Negro                     40   14  25.648241     55.0  20.0  34.678571
# Município ignorado - RO         24   24  24.000000     22.0  22.0  22.000000
# Nova Brasilândia D'Oeste        51   15  26.222222     48.0  20.0  30.520833
# Nova Mamoré                     46   14  25.326389     43.0  19.0  31.692308
# Nova União                      39   16  26.894231     53.0  18.0  31.371429
# Novo Horizonte do Oeste         41   15  26.938776     56.0  20.0  31.588235
# Ouro Preto do Oeste             44   14  26.375594     60.0  17.0  31.233244
# Parecis                         41   16  26.454545     61.0  18.0  32.473684
# Pimenta Bueno                   47   13  25.199675     70.0  16.0  29.745174
# Pimenteiras do Oeste            40   14  25.075000     45.0  25.0  35.600000
# Porto Velho                     47   12  26.312670     65.0  16.0  32.352679
# Presidente Médici               44   14  25.796053     64.0  16.0  30.150754
# Primavera de Rondônia           39   16  27.023256     44.0  21.0  31.888889
# Rio Crespo                      39   16  26.660000     28.0  28.0  28.000000
# Rolim de Moura                  44   14  26.600863     69.0  16.0  30.360479
# Santa Luzia D'Oeste             41   15  26.121212     53.0  18.0  30.703297
# Seringueiras                    42   14  24.910714     47.0  20.0  30.500000
# São Felipe D'Oeste              41   17  26.481481     57.0  18.0  31.395833
# São Francisco do Guaporé        41   14  25.660066     54.0  19.0  31.638889
# São Miguel do Guaporé           42   14  25.926346     60.0  19.0  32.666667
# Teixeirópolis                   39   16  26.031250     67.0  20.0  31.500000
# Theobroma                       42   15  25.536082     45.0  23.0  30.083333
# Urupá                           43   15  26.688235     48.0  17.0  31.008929
# Vale do Anari                   44   14  26.096774     58.0  23.0  34.000000
# Vale do Paraíso                 52   14  25.679012     51.0  18.0  29.976744
# Vilhena                         46   14  26.433962     60.0  18.0  34.152941
#
#                            PESO                    QTDFILMORT                 \
#                            amax  amin         mean       amax amin      mean
# munResNome
# Alta Floresta D'Oeste      4980   370  3240.841962        3.0  0.0  0.201102
# Alto Alegre dos Parecis    4430  1335  3261.383117        3.0  0.0  0.181208
# Alto Paraíso               4450   750  3217.969027        3.0  0.0  0.248848
# Alvorada D'Oeste           4855  1353  3225.712195        2.0  0.0  0.183168
# Ariquemes                  4985   345  3251.362637        5.0  0.0  0.243448
# Buritis                    4645   345  3229.876501        6.0  0.0  0.623256
# Cabixi                     4375  2235  3336.100000        2.0  0.0  0.262500
# Cacaulândia                4190  1980  3232.360000        3.0  0.0  0.202703
# Cacoal                     5470   315  3249.720524        5.0  0.0  0.246896
# Campo Novo de Rondônia     4680   930  3227.969880        3.0  0.0  0.396396
# Candeias do Jamari         5135  1180  3296.305638        5.0  0.0  0.304348
# Castanheiras               4255  2280  3206.312500        1.0  0.0  0.093750
# Cerejeiras                 4790   355  3168.367089        3.0  0.0  0.303030
# Chupinguaia                4415   990  3317.419753        3.0  0.0  0.193750
# Colorado do Oeste          4888   258  3231.897196        3.0  0.0  0.257009
# Corumbiara                 4810   790  3294.685039        3.0  0.0  0.190476
# Costa Marques              4570   425  3249.721030        6.0  0.0  0.261062
# Cujubim                    4630  1245  3292.243902        3.0  0.0  0.238806
# Espigão D'Oeste            5985   555  3257.300000        3.0  0.0  0.216216
# Governador Jorge Teixeira  4140  1930  3238.991071        2.0  0.0  0.185185
# Guajará-Mirim              5070   460  3293.094750        7.0  0.0  0.315927
# Itapuã do Oeste            4160  2160  3308.834862        2.0  0.0  0.275510
# Jaru                       5190   404  3277.671964        4.0  0.0  0.233677
# Ji-Paraná                  5480   292  3253.078368        3.0  0.0  0.227608
# Machadinho D'Oeste         5065   500  3197.368000        9.0  0.0  0.238994
# Ministro Andreazza         4490  1725  3135.595238        2.0  0.0  0.345238
# Mirante da Serra           4410   875  3147.585366        3.0  0.0  0.271605
# Monte Negro                4300  1238  3217.060302        4.0  0.0  0.251337
# Município ignorado - RO    3215  3215  3215.000000        1.0  1.0  1.000000
# Nova Brasilândia D'Oeste   4534   704  3134.808429        3.0  0.0  0.189922
# Nova Mamoré                4700   730  3248.851852        6.0  0.0  0.332461
# Nova União                 4390  1025  3193.221154        2.0  0.0  0.126214
# Novo Horizonte do Oeste    4355  1060  3244.744898        3.0  0.0  0.329897
# Ouro Preto do Oeste        4650   285  3226.835182        3.0  0.0  0.270833
# Parecis                    4160  1790  3096.363636        1.0  0.0  0.095238
# Pimenta Bueno              4885   630  3305.430195        4.0  0.0  0.205980
# Pimenteiras do Oeste       4215  2550  3340.350000        1.0  0.0  0.175000
# Porto Velho                5060   295  3242.820078        9.0  0.0  0.309770
# Presidente Médici          4726   580  3173.065789        4.0  0.0  0.232558
# Primavera de Rondônia      4235   320  3185.581395        2.0  0.0  0.209302
# Rio Crespo                 4505   990  3202.760000        2.0  0.0  0.319149
# Rolim de Moura             5720   690  3223.445523        4.0  0.0  0.260065
# Santa Luzia D'Oeste        4180  1640  3213.606061        2.0  0.0  0.193878
# Seringueiras               4700  1140  3289.142857        4.0  0.0  0.233533
# São Felipe D'Oeste         4370   810  3106.574074        2.0  0.0  0.094340
# São Francisco do Guaporé   4760   560  3295.564356        5.0  0.0  0.278523
# São Miguel do Guaporé      4710   350  3177.988669        3.0  0.0  0.240688
# Teixeirópolis              4435  1990  3185.250000        2.0  0.0  0.203125
# Theobroma                  4785  1455  3227.865979        3.0  0.0  0.231579
# Urupá                      4500   985  3190.941176        2.0  0.0  0.247059
# Vale do Anari              4395   845  3223.806452        2.0  0.0  0.152174
# Vale do Paraíso            4750  1393  3353.925926        3.0  0.0  0.215190
# Vilhena                    4920   425  3230.250314       28.0  0.0  0.251580
#
#                           QTDFILVIVO
#                                 amax amin      mean
# munResNome
# Alta Floresta D'Oeste            7.0  0.0  0.856354
# Alto Alegre dos Parecis          5.0  0.0  0.907895
# Alto Paraíso                     6.0  0.0  1.162896
# Alvorada D'Oeste                 9.0  0.0  0.975248
# Ariquemes                        8.0  0.0  0.962253
# Buritis                         10.0  0.0  1.353846
# Cabixi                           4.0  0.0  0.762500
# Cacaulândia                      7.0  0.0  1.013333
# Cacoal                           7.0  0.0  0.899123
# Campo Novo de Rondônia           5.0  0.0  1.160305
# Candeias do Jamari               8.0  0.0  1.433775
# Castanheiras                     6.0  0.0  1.062500
# Cerejeiras                       8.0  0.0  0.987124
# Chupinguaia                      8.0  0.0  1.081250
# Colorado do Oeste                8.0  0.0  0.934579
# Corumbiara                       4.0  0.0  0.849206
# Costa Marques                   14.0  0.0  1.258772
# Cujubim                          7.0  0.0  1.256158
# Espigão D'Oeste                 12.0  0.0  1.405830
# Governador Jorge Teixeira        5.0  0.0  0.768519
# Guajará-Mirim                   11.0  0.0  1.543563
# Itapuã do Oeste                  6.0  0.0  1.410000
# Jaru                             7.0  0.0  0.891304
# Ji-Paraná                        8.0  0.0  0.933272
# Machadinho D'Oeste              10.0  0.0  1.114286
# Ministro Andreazza               6.0  0.0  1.095238
# Mirante da Serra                 5.0  0.0  0.932515
# Monte Negro                      7.0  0.0  0.989583
# Município ignorado - RO          1.0  1.0  1.000000
# Nova Brasilândia D'Oeste         4.0  0.0  0.879845
# Nova Mamoré                      8.0  0.0  1.295455
# Nova União                       4.0  0.0  0.844660
# Novo Horizonte do Oeste          4.0  0.0  0.835052
# Ouro Preto do Oeste              6.0  0.0  0.899361
# Parecis                          5.0  0.0  1.302326
# Pimenta Bueno                    9.0  0.0  0.863934
# Pimenteiras do Oeste             5.0  0.0  1.150000
# Porto Velho                     12.0  0.0  1.167236
# Presidente Médici                7.0  0.0  0.930233
# Primavera de Rondônia            4.0  0.0  1.093023
# Rio Crespo                       4.0  0.0  1.255319
# Rolim de Moura                   5.0  0.0  0.858542
# Santa Luzia D'Oeste             30.0  0.0  1.171717
# Seringueiras                     5.0  0.0  0.880240
# São Felipe D'Oeste               5.0  0.0  0.773585
# São Francisco do Guaporé         6.0  0.0  1.079734
# São Miguel do Guaporé            6.0  0.0  0.891117
# Teixeirópolis                    6.0  0.0  0.859375
# Theobroma                        4.0  0.0  0.905263
# Urupá                            5.0  0.0  0.946746
# Vale do Anari                    8.0  0.0  1.173913
# Vale do Paraíso                  4.0  0.0  0.696203
# Vilhena                         10.0  0.0  0.917929

# %%
x = table_3['IDADEMAE']['amin']
y = table_3['QTDFILMORT']['mean']

sns.scatterplot(data=table_3, x=x, y=y)
plt.xlabel('IDADE MIN MAE')
plt.ylabel('QTDFILMORT MEDIA')
# Out:
# Text(0, 0.5, 'QTDFILMORT MEDIA')

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# - Quando a idade mínima das mães é menor do que 18, a quantidade média de filhos mortos aumenta significativamente.
