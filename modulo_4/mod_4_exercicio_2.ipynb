# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
# importando as bibliotecas

import pandas as pd
import numpy as np

# %%
# cria um pd.dataframe a partir de um dicionario

banco_questoes = {'disciplinas':['matematica', 'portugues', 'geografia', 'ingles', 'historia', 'fisica', 'quimica'],
                  'numero_questoes':[24,18,8,8,8,12,12]}

df_questoes = pd.DataFrame(data=banco_questoes)
df_questoes.head(7)
# Out:
#   disciplinas  numero_questoes
# 0  matematica               24
# 1   portugues               18
# 2   geografia                8
# 3      ingles                8
# 4    historia                8
# 5      fisica               12
# 6     quimica               12

# %%
total_questoes = df_questoes['numero_questoes'].sum()
total_questoes
# Out:
# 90

# %%
# cria um df para a quantidade de questoes totais (qt)

qt_mat = df_questoes.iloc[0,1]
qt_por = df_questoes.iloc[1,1]
qt_geo = df_questoes.iloc[2,1]
qt_ing = df_questoes.iloc[3,1]
qt_his = df_questoes.iloc[4,1]
qt_fis = df_questoes.iloc[5,1]
qt_qui = df_questoes.iloc[6,1]

# %%
# de fato, um inteiro

type(qt_qui)
# Out:
# numpy.int64

# %%
np.random.seed(42)

# %%
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# exemplo de uma amostra de dados (matemática)

df_mat.head(5)
# Out:
#    Qt_acertos mat
# 0              11
# 1              21
# 2               6
# 3               9
# 4              18

# %%
# 1) Seu código aqui

pc_mat = (df_mat/qt_mat).mul(100).round(2)
pc_por = (df_por/qt_por).mul(100).round(2)
pc_geo = (df_geo/qt_geo).mul(100).round(2)
pc_ing = (df_ing/qt_ing).mul(100).round(2)
pc_his = (df_his/qt_his).mul(100).round(2)
pc_fis = (df_fis/qt_fis).mul(100).round(2)
pc_qui = (df_qui/qt_qui).mul(100).round(2)

# %%
pc_mat.head()
# Out:
#    Qt_acertos mat
# 0           45.83
# 1           87.50
# 2           25.00
# 3           37.50
# 4           75.00

# %%
# 2) Seu código aqui
total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
total
# Out:
#     Qt_acertos
# 0           53
# 1           48
# 2           39
# 3           56
# 4           45
# ..         ...
# 95          33
# 96          41
# 97          52
# 98          49
# 99          38
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
pc_total = (total/total_questoes).mul(100).round(2)
pc_total
# Out:
#     Qt_acertos
# 0        58.89
# 1        53.33
# 2        43.33
# 3        62.22
# 4        50.00
# ..         ...
# 95       36.67
# 96       45.56
# 97       57.78
# 98       54.44
# 99       42.22
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui
total_45 = total[total['Qt_acertos'] > 45]
total_45.count()
# Out:
# Qt_acertos    31
# dtype: int64

# %%
# Se fosse 45% de aprovação:

pc_total[pc_total['Qt_acertos'] > 45].count()
# Out:
# Qt_acertos    47
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
df_eliminados = total[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)]

df_eliminados.head()
# Out:
#     Qt_acertos
# 2           39
# 5           28
# 6           37
# 14          31
# 17          36

# %%
linha,_ = df_eliminados.shape

print(f'{linha} alunos foram eliminados')
# Out:
# 20 alunos foram eliminados

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
# 1) Sua solução aqui
df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')

# %%
df.drop(columns=['paciente_id','document_id']).head(5)
# Out:
#    paciente_idade paciente_datanascimento paciente_enumsexobiologico  \
# 0              69              1951-12-28                          F
# 1              81              1939-11-22                          M
# 2              69              1951-08-14                          M
# 3              51              1969-12-15                          F
# 4              65              1955-11-21                          M
#
#    paciente_racacor_codigo paciente_racacor_valor  \
# 0                        3                  PARDA
# 1                        3                  PARDA
# 2                        4                AMARELA
# 3                        3                  PARDA
# 4                        3                  PARDA
#
#    paciente_endereco_coibgemunicipio  paciente_endereco_copais  \
# 0                           120050.0                      10.0
# 1                           120040.0                      10.0
# ...

# %%
total,_ = df.shape

print(f'Total de Vacinados (ambas doses): {total}.')
# Out:
# Total de Vacinados (ambas doses): 169071.

# %%
# 2) 

print(f"Pacientes registrados unicamente: {df['paciente_id'].nunique()}\n")

print(f"Registtros duplos: {total - df['paciente_id'].nunique()}")
# Out:
# Pacientes registrados unicamente: 120517
#
# Registtros duplos: 48554

# %%
df['vacina_descricao_dose'].value_counts()
# Out:
#     1ª Dose    120939
#     2ª Dose     48107
#     Dose           25
# Name: vacina_descricao_dose, dtype: int64

# %% [markdown]
# O valor 'Dose' será entendido como erro de preenchimento.

# %%
# 3) 
uma_dose = df['vacina_descricao_dose'].unique()[0]  # busca o elemento único '1 Dose'
pacientes_uma_dose = df['paciente_id'].loc[df['vacina_descricao_dose'] == uma_dose].nunique()

pacientes_uma_dose
# Out:
# 119713

# %%
# 4) 
df_menor = df[df["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 49

# %%
# 5)
df['estabelecimento_razaosocial'].nunique()
# Out:
# 42

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) 
df_menor = df[df["paciente_idade"]<18].copy()
df_menor.head()
# Out:
#                                      document_id  \
# 1567   fdca313f-b348-422d-94d4-f2c66a87868c-i0b0
# 6250   b7431955-1faa-4c1e-9246-7c1e7b8bb3cb-i0b0
# 9569   fdb8d3b6-14d9-4bcc-9cfe-acd46b4a317a-i0b0
# 11338  647e2301-3ba4-463a-8d1e-2b6f38a4d99e-i0b0
# 15144  7f469e03-bece-49d0-bebc-33ad98e27f54-i0b0
#
#                                              paciente_id  paciente_idade  \
# 1567   f5e6b8c44f7c4d13a87c582def5e8d460435b02f26af8c...              17
# 6250   e1a45c07e3c393d5f0eccf4204a7ceab338f4f06696ecb...              16
# 9569   7cf3b238383a70eeb26841c01817737c9706d5b231e8c2...              17
# 11338  53eb7fed5faa26ad17ce21ee378f28e25399ab7e90bc05...              17
# 15144  dbaa6420d8a815158387668d0a59a19cf2bb63958e35d1...              16
#
#       paciente_datanascimento paciente_enumsexobiologico  \
# 1567               2003-07-18                          F
# 6250               2004-05-18                          M
# ...

# %%
# 2) 
colunas = df_menor.columns.tolist()

print(colunas)
# Out:
# ['document_id', 'paciente_id', 'paciente_idade', 'paciente_datanascimento', 'paciente_enumsexobiologico', 'paciente_racacor_codigo', 'paciente_racacor_valor', 'paciente_endereco_coibgemunicipio', 'paciente_endereco_copais', 'paciente_endereco_nmmunicipio', 'paciente_endereco_nmpais', 'paciente_endereco_uf', 'paciente_endereco_cep', 'paciente_nacionalidade_enumnacionalidade', 'estabelecimento_valor', 'estabelecimento_razaosocial', 'estalecimento_nofantasia', 'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome', 'estabelecimento_uf', 'vacina_grupoatendimento_codigo', 'vacina_grupoatendimento_nome', 'vacina_categoria_codigo', 'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome', 'vacina_fabricante_referencia', 'vacina_dataaplicacao', 'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome', 'sistema_origem', 'data_importacao_rnds', 'id_sistema_origem']

# %%
# 3)
vacina_categoria_dic = df_menor['vacina_categoria_nome'].value_counts().to_dict()

print(vacina_categoria_dic)
# Out:
# {'Povos Indígenas': 33, 'Trabalhadores de Saúde': 9, 'Povos e Comunidades Tradicionais': 9, 'Comorbidades': 2, 'Faixa Etária': 1}

# %%
# 4)

estabelecimentos = ['estabelecimento_valor',
       'estabelecimento_razaosocial', 'estalecimento_nofantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']
df_menor_lista = df_menor.loc[:, estabelecimentos]

df_menor_lista.head(5)
# Out:
#        estabelecimento_valor  \
# 1567                 2001314
# 6250                 6917291
# 9569                 6159087
# 11338                2000040
# 15144                7625855
#
#                              estabelecimento_razaosocial  \
# 1567              PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 6250                  PREFEITURA MUNICIPAL DE RIO BRANCO
# 9569             PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 11338                      PREFEITURA MUNICIPAL DE FEIJO
# 15144  DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
#
#                                 estalecimento_nofantasia  \
# 1567                             ESF JOAO ALVES DA SILVA
# 6250   DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 9569    SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL
# 11338                  CENTRO DE SAUDE DIAMANTINO MACEDO
# 15144                  POLO BASE DE MARECHAL THAUMATURGO
#
#        estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# ...

# %%
df_menor_lista.nunique()
# Out:
# estabelecimento_valor               18
# estabelecimento_razaosocial         14
# estalecimento_nofantasia            18
# estabelecimento_municipio_codigo    13
# estabelecimento_municipio_nome      13
# estabelecimento_uf                   1
# dtype: int64

# %%
print(df_menor.shape)
# Out:
# (55, 34)

# %%
# 5)

# filtrando pelo código do estabelecimento junto ao municipio
df_menor_lista = df_menor_lista.drop_duplicates('estabelecimento_municipio_codigo')
df_menor_lista.shape
# Out:
# (13, 6)

# %%
df_menor_lista.nunique()
# Out:
# estabelecimento_valor               13
# estabelecimento_razaosocial         11
# estalecimento_nofantasia            13
# estabelecimento_municipio_codigo    13
# estabelecimento_municipio_nome      13
# estabelecimento_uf                   1
# dtype: int64

# %%
df_menor_lista.head()
# Out:
#        estabelecimento_valor  \
# 1567                 2001314
# 6250                 6917291
# 9569                 6159087
# 11338                2000040
# 15144                7625855
#
#                              estabelecimento_razaosocial  \
# 1567              PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 6250                  PREFEITURA MUNICIPAL DE RIO BRANCO
# 9569             PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 11338                      PREFEITURA MUNICIPAL DE FEIJO
# 15144  DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
#
#                                 estalecimento_nofantasia  \
# 1567                             ESF JOAO ALVES DA SILVA
# 6250   DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 9569    SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL
# 11338                  CENTRO DE SAUDE DIAMANTINO MACEDO
# 15144                  POLO BASE DE MARECHAL THAUMATURGO
#
#        estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# ...
